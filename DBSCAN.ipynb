# %% [markdown]
# <a href="https://colab.research.google.com/github/KeerthiErnapu/DMDW/blob/main/DBSCAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN

# %%
data=pd.read_csv('/content/IRIS (1).csv')

# %%
x=data.drop('species',axis=1)

# %%
db=DBSCAN(eps=0.5,min_samples=3)

# %%
db.fit(x)
# Out:
# DBSCAN(min_samples=3)

# %%
labels=db.labels_

# %%
plt.scatter(x['sepal_length'],x['sepal_width'],c=labels)
plt.show()
